# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

# %matplotlib inline
plt.rcParams.update({'font.size': 12})
n_jobs=-1 #number of threads

# %%
shapes = ["TtauNL","TgNL","Teq1","Teq2","Teq3"]
ks = [0.3,1,3,10,30,100,300]
b = 0
for shapy in shapes:
    Fish = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataPrim = np.genfromtxt(f"Secondaries7ks{shapy}.dat")

    datasec = dataSec.copy()
    dataprim = dataPrim.copy()

    datasec[:,-2] *= np.random.normal(loc=1,scale=datasec[:,-1])
    dataprim[:,-2] *= np.random.normal(loc=1,scale=dataprim[:,-1])

    a = 0
    for ki in range(len(ks)):
        for S1 in range(7):
            for S2 in range(S1,7):
                Fish[ki,S1,S2] = Fish[ki,S2,S1] = datasec[a,-2]
                a+=1

    a = 0
    for ki in range(len(ks)):
        for S1 in range(8):
                Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataprim[a,-2]
                a+=1

    FishInv = np.linalg.inv(Fish)
    plt.semilogx(ks,Fish[:,-1,-1]*FishInv[:,-1,-1])
    # print(results[:,i])

# %%
shapes = ["TtauNL","TgNL","Teq1","Teq2","Teq3"]
ks = [0.3,1,3,10,30,100,300]
final_results = np.zeros((len(shapes),7))
b = 0
for shapy in shapes:
    Fish = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataPrim = np.genfromtxt(f"Secondaries7ks{shapy}.dat")
    

    fig, axs = plt.subplots(1,2, figsize=(20,5))

    N = 100
    results = np.zeros((len(ks),N))
    for i in range(N):

        datasec = dataSec.copy()
        dataprim = dataPrim.copy()

        datasec[:,-2] *= np.random.normal(loc=1,scale=datasec[:,-1])
        dataprim[:,-2] *= np.random.normal(loc=1,scale=dataprim[:,-1])

        a = 0
        for ki in range(len(ks)):
            for S1 in range(7):
                for S2 in range(S1,7):
                    Fish[ki,S1,S2] = Fish[ki,S2,S1] = datasec[a,-2]
                    a+=1

        a = 0
        for ki in range(len(ks)):
            for S1 in range(8):
                    Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataprim[a,-2]
                    a+=1

        FishInv = np.linalg.inv(Fish)
        results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
        # print(results[:,i])
        axs[1].semilogx(ks,results[:,i])
#         axs[1].loglog(ks,FishInv[:,-1,-1]**(1/2))
#         axs[1].loglog(ks,Fish[:,-1,-1]**(-1/2),"--")
        [axs[0].plot([Fish[ki,n,-1]/np.sqrt(Fish[ki,n,n]*Fish[ki,-1,-1]) for n in range(7)]) for ki in range(len(ks))]

    mean = np.nanmean(results,axis=1)
    rerr = np.nanstd(results,axis=1)/np.nanmean(results,axis=1)
    print(shapy,mean,rerr)
    final_results[b,:]= mean
    axs[0].set_ylim(-1,1)
    axs[1].set_ylim(1,2)
    axs[0].plot([-1,7],[0,0],'k')
    axs[0].set_xlim(0,6)
    plt.show()
    b+=1
# Out:
# TtauNL [1.07294947 1.03959495 1.03323681 1.03066275 1.03028888 1.03069512
#  1.02953806] [0.00282415 0.00092798 0.00029211 0.00026209 0.00024409 0.00385885
#  0.00026526]
# TgNL [1.16880278 1.13655863 1.12631829 1.1265908  1.128654   1.13688924
#  1.15177234] [0.00172068 0.00033438 0.00038311 0.00191394 0.00076489 0.00341849
#  0.00151991]
# /local/tmp/ipykernel_12611/1408196652.py:37: RuntimeWarning: invalid value encountered in sqrt
#   results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
# Teq1 [1.26580409 1.21431041 1.15841973 1.10977334 1.08096017 1.06067166
#  1.04124283] [0.00186815 0.00111655 0.00050587 0.00860528 0.00028535 0.00047105
#  0.00029452]
# Teq2 [1.26334049 1.20352991 1.13971546 1.08817684 1.06176606 1.04511747
#  1.02869121] [0.00426829 0.00137064 0.00072918 0.00602116 0.00037053 0.00034636
#  0.00027372]
# /local/tmp/ipykernel_12611/1408196652.py:37: RuntimeWarning: invalid value encountered in sqrt
#   results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
# Teq3 [1.19622759 1.13826441 1.08431735 1.04579316 1.02711531 1.01861645
#  1.01185469] [0.00194935 0.00122152 0.00077035 0.00173119 0.00028208 0.00449236
#  0.00024229]

# %%
primshapes = ["$\\tau_{NL}^{loc}$","$g_{NL}^{loc}$",'$g_{NL}^{\dot{\sigma}^4}$','$g_{NL}^{\sigma^2(\partial\sigma)^2}$','$g_{NL}^{(\partial \sigma)^4}$']
[plt.semilogx(ks,(final_results.T)[:,i],"-",label=primshapes[i]) for i in range(5)]
plt.grid(linestyle=":")
plt.legend()
plt.xlabel("$k_{max}$")
plt.ylabel("SND")
plt.ylim(1,1.3)
plt.xlim(0.3,300)
plt.xticks(ks,[str(k) for k in ks])
plt.savefig("SNDTrispectrumPrim.pdf",format='pdf')
plt.show()

# %%
mus = [0.25,0.5,1,2,6]
ks = [0.3,1,3,10,30,100,300]
final_results = np.zeros((len(mus),7))
b = 0

N=1000

for mu in mus:
    Fish = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataPrim = np.genfromtxt(f"Secondaries7ksTClock{mu}.dat")
    results = np.zeros((len(ks),N))

    fig, axs = plt.subplots(1,2, figsize=(20,5))

    for i in range(N):

        datasec = dataSec.copy()
        dataprim = dataPrim.copy()

        datasec[:,-2] *= np.random.normal(loc=1,scale=datasec[:,-1])
        dataprim[:,-2] *= np.random.normal(loc=1,scale=dataprim[:,-1])

        a = 0
        for ki in range(len(ks)):
            for S1 in range(7):
                for S2 in range(S1,7):
                    Fish[ki,S1,S2] = Fish[ki,S2,S1] = datasec[a,-2]
                    a+=1

        a = 0
        for ki in range(len(ks)):
            for S1 in range(8):
                    Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataprim[a,-2]
                    a+=1

        FishInv = np.linalg.inv(Fish)
        results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
        axs[1].semilogx(ks,results[:,i])
        [axs[0].plot([Fish[ki,n,-1]/np.sqrt(Fish[ki,n,n]*Fish[ki,-1,-1]) for n in range(7)]) for ki in range(len(ks))]

    mean = np.nanmean(results,axis=1)
    rerr = np.nanstd(results,axis=1)/np.nanmean(results,axis=1)
    print(mu,mean,rerr)
    final_results[b,:]= mean
    axs[0].set_ylim(-1,1)
    axs[0].plot([-1,7],[0,0],'k')
    axs[0].set_xlim(0,6)
    plt.show()
    b+=1
# Out:
# 0.25 [1.16140791 1.10943046 1.06365952 1.03668079 1.02523072 1.01834412
#  1.01142212] [4.05218203e-03 1.32562394e-03 3.21810401e-04 8.31029815e-03
#  1.10221512e-04 3.59655397e-04 8.67122201e-05]
# 0.5 [1.13498907 1.08797186 1.05428685 1.03539949 1.02414947 1.01746144
#  1.01072098] [1.33790220e-02 7.54098805e-04 2.29103582e-04 4.89534865e-02
#  1.02300599e-04 3.89468857e-04 8.10464393e-05]
# <ipython-input-29-e7993542fdd3>:38: RuntimeWarning: invalid value encountered in sqrt
#   results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
# 1 [1.06323    1.04091315 1.02565473 1.01570143 1.01078867 1.00751067
#  1.0041692 ] [3.83776776e-04 2.94507736e-04 1.16874191e-04 2.31743889e-03
#  4.71690010e-05 8.49246414e-04 3.09361306e-05]
# 2 [1.04772348 1.0326333  1.02126446 1.01336154 1.00926015 1.00656636
#  1.00374045] [2.75768221e-04 2.03537361e-04 9.07641251e-05 1.73894964e-03
#  4.11517354e-05 7.87559850e-05 2.85651527e-05]
# 6 [1.00247411 1.00156738 1.00097846 1.00061311 1.00043137 1.00030192
#  1.00016403] [2.54961122e-05 1.46213494e-05 5.99981099e-06 2.70217582e-04
#  2.35960209e-06 3.23532550e-06 1.40011839e-06]

# %%
[plt.semilogx(ks,(final_results.T)[:,i],"-",label=f"$\\mu = {mus[i]}$") for i in range(5)]
plt.grid(linestyle=":")
plt.legend()
plt.xlabel("$k_{max}$")
plt.xlim(0.3,300)
plt.ylim(1,1.2)
plt.ylabel("SND")
plt.xticks(ks,[str(k) for k in ks])
plt.savefig("SNDTrispectrumClock.pdf",format='pdf')
plt.show()

# %%
mus = [0.1,0.5,1,1.25,1.4]
ks = [0.3,1,3,10,30,100,300]
final_results = np.zeros((len(mus),7))
b = 0

N=1000

for mu in mus:
    Fish = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataPrim = np.genfromtxt(f"Secondaries7ksTInt{mu}.dat")
    results = np.zeros((len(ks),N))

    fig, axs = plt.subplots(1,2, figsize=(20,5))

    for i in range(N):

        datasec = dataSec.copy()
        dataprim = dataPrim.copy()

#         datasec[:,-2] *= np.random.normal(loc=1,scale=datasec[:,-1])
        dataprim[:,-2] *= np.random.normal(loc=1,scale=dataprim[:,-1])

        a = 0
        for ki in range(len(ks)):
            for S1 in range(7):
                for S2 in range(S1,7):
                    Fish[ki,S1,S2] = Fish[ki,S2,S1] = datasec[a,-2]
                    a+=1

        a = 0
        for ki in range(len(ks)):
            for S1 in range(8):
                    Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataprim[a,-2]
                    a+=1

        FishInv = np.linalg.inv(Fish)
        results[:,i] = np.sqrt(Fish[:,-1,-1]*FishInv[:,-1,-1])
        axs[1].semilogx(ks,results[:,i])
        [axs[0].plot([Fish[ki,n,-1]/np.sqrt(Fish[ki,n,n]*Fish[ki,-1,-1]) for n in range(7)]) for ki in range(len(ks))]

    mean = np.nanmean(results,axis=1)
    rerr = np.nanstd(results,axis=1)/np.nanmean(results,axis=1)
    print(mu,mean,rerr)
    final_results[b,:]= mean
    axs[0].set_ylim(-1,1)
    axs[0].plot([-1,7],[0,0],'k')
    axs[0].set_xlim(0,6)
    plt.show()
    b+=1
# Out:
# 0.1 [1.12875807 1.08544013 1.05030242 1.02948037 1.02002982 1.01421403
#  1.00879118] [1.95882352e-03 8.06063843e-04 3.21150404e-04 1.65022170e-04
#  1.06416282e-04 7.68238041e-05 4.69577708e-05]
# 0.5 [1.17680568 1.15123062 1.09508476 1.05132236 1.02924248 1.01738913
#  1.01020946] [2.80823638e-03 1.93205220e-03 7.02279895e-04 2.60037850e-04
#  1.25492430e-04 8.14198358e-05 4.93100266e-05]
# 1 [1.1466866  1.12682693 1.1227514  1.11995793 1.12039984 1.12110109
#  1.11988894] [0.0024949  0.00115893 0.00064828 0.00060187 0.00057243 0.00075193
#  0.00061144]
# 1.25 [1.09341013 1.06478339 1.05982128 1.05706212 1.05707974 1.05697329
#  1.05544305] [0.00144015 0.00033067 0.00028833 0.00027189 0.00025511 0.00035292
#  0.00026709]
# 1.4 [1.06756913 1.04552835 1.04078311 1.03872538 1.03820273 1.03758938
#  1.03712107] [0.00078124 0.00022111 0.00019522 0.00019062 0.00017463 0.00022333
#  0.00017906]

# %%
[plt.semilogx(ks,(final_results.T)[:,i],"-",label=f"$\\nu = {mus[i]}$") for i in range(len(mus))]
plt.grid(linestyle=":")
plt.legend()
plt.xlabel("$k_{max}$")
plt.ylabel("SND")
plt.xlim(0.3,300)
plt.ylim(1,1.25)
plt.xticks(ks[:],[str(k) for k in ks[:]])
plt.savefig("SNDTrispectrumInt.pdf",format='pdf')
plt.show()

# %%
shapes = ["TtauNL","TgNL","Teq1","Teq2","Teq3"]
primshapes = ["$\\tau_{NL}^{loc}$","$g_{NL}^{loc}$",'$g_{NL}^{\dot{\sigma}^4}$','$g_{NL}^{\dot{\sigma}^2(\partial\sigma)^2}$','$g_{NL}^{(\partial \sigma)^4}$']
colors = ["tab:blue","tab:orange","tab:green","tab:red","tab:purple"]
ks = [0.3,1,3,10,30,100,300]
final_results = np.zeros((len(shapes),7))
b = 0
for shapy in shapes:
    Fish = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataPrim = np.genfromtxt(f"Secondaries7ks{shapy}.dat")

    datasec = dataSec.copy()
    dataprim = dataPrim.copy()

    datasec[:,-2] *= np.random.normal(loc=1,scale=datasec[:,-1])
    dataprim[:,-2] *= np.random.normal(loc=1,scale=dataprim[:,-1])

    a = 0
    for ki in range(len(ks)):
        for S1 in range(7):
            for S2 in range(S1,7):
                Fish[ki,S1,S2] = Fish[ki,S2,S1] = datasec[a,-2]
                a+=1

    a = 0
    for ki in range(len(ks)):
        for S1 in range(8):
                Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataprim[a,-2]
                a+=1

    FishInv = np.linalg.inv(Fish)

    plt.loglog(ks,FishInv[:,-1,-1]**(1/2),label=primshapes[b],color=colors[b])
    plt.loglog(ks,Fish[:,-1,-1]**(-1/2),"--",color=colors[b])
#     if b==0:
#         plt.xlim(0.3,300)
#         plt.xticks(ks,[str(k) for k in ks])
#         plt.xlabel("$k_{max}$")
#         plt.ylabel("$\sigma_f$")
#         plt.legend()    
#         plt.grid()
#         plt.show()
    print(Fish[-1,-1,-1]**(-1/2))
    b+=1
    
    
plt.xlim(0.3,300)
plt.xticks(ks,[str(k) for k in ks])
plt.xlabel("$k_{max}$")
plt.ylabel("$\sigma_g$")
plt.legend()    
plt.grid(linestyle=":")
plt.savefig("TrispectrumCommonError.pdf",format='pdf')
plt.show()
# Out:
# 1.794015506197227e-07
# 0.03104615131993832
# 0.22852224055185458
# 0.25367754735531994
# 0.06077428015294216

# %%
mus = [0.25,0.5,1,2,6]
ks = [0.3,1,3,10,30,100,300]
# shapes = ["TtauNL","TgNL","Teq1","Teq2","Teq3"]
shapes = ["Teq1","Teq2","Teq3","TgNL","TtauNL"]
primshapes = ["$\\tau_{NL}^{loc}$","$g_{NL}^{loc}$",'$g_{NL}^{\dot{\sigma}^4}$','$g_{NL}^{\dot{\sigma}^2(\partial\sigma)^2}$','$g_{NL}^{(\partial \sigma)^4}$']
colors = ["tab:blue","tab:orange","tab:green","tab:red","tab:purple"]

b=0
for mu in mus:
    Fish = np.zeros((len(ks),13,13))
    FishSecOnly = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataSecClock = np.genfromtxt(f"Secondaries7ksTClock{mu}.dat")
    dataPrim = np.genfromtxt("PrimOverlaps7ks.dat")
    dataPrimClock = np.genfromtxt(f"PrimClockOverlaps7ks{mu}.dat")

    #fill the first 7x7 block with secondaries
    a = 0
    for ki in range(len(ks)):
        for S1 in range(7):
            for S2 in range(S1,7):
                Fish[ki,S1,S2] = Fish[ki,S2,S1] = dataSec[a,-2]
                a+=1
                
    FishSecOnly[:,:-1,:-1] = Fish[:,:7,:7]
                
    #fill the prim x secondaries:
    for si, shape in enumerate(shapes):
        dataSecPrim = np.genfromtxt(f"Secondaries7ks{shape}.dat")
        a = 0
        for ki in range(len(ks)):
            for S1 in range(8):
                if S1 == 7:
                    Fish[ki,7+si,7+si] = dataSecPrim[a,-2]
                else:
                    Fish[ki,S1,7+si] = Fish[ki,7+si,S1] = dataSecPrim[a,-2]
                a+=1

    #fill the prim x prim block
    a = 0
    for ki in range(len(ks)):
        for S1 in range(5):
            for S2 in range(S1,5):
                if S1 == S2:
                    sadslkfjsdf = 1
                else:
                    Fish[ki,7+S1,7+S2] = Fish[ki,7+S2,7+S1] = dataPrim[a,-2]
                a+=1

    #fill the sec x clock row&column

    a = 0
    for ki in range(len(ks)):
        for S1 in range(8):
            if S1 == 7:
                Fish[ki,-1,-1] = dataSecClock[a,-2]
            else:
                Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataSecClock[a,-2]
            a+=1
            
    #fill the prim x clock parts
    a = 0
    for ki in range(len(ks)):
        for S1 in range(5):
            Fish[ki,7+S1,-1] = Fish[ki,-1,7+S1] = dataPrimClock[a,-2]
            a+=1

    FishPrimOnly = Fish[:,8:,8:]
    FishSecOnly[:,-1,-1] = Fish[:,-1,-1]
            
    FishInv = np.linalg.inv(Fish)
    FishSecOnlyInv = np.linalg.inv(FishSecOnly)
    FishPrimOnlyInv = np.linalg.inv(FishPrimOnly)
#     plt.loglog(ks,Fish[:,-1,-1]**(-1/2),"--",color=colors[b])
    plt.loglog(ks,FishInv[:,-1,-1]**(1/2),label=f"$\\mu = {mu}$",linestyle="-",color=colors[b])
#     plt.loglog(ks,FishSecOnlyInv[:,-1,-1]**(1/2),":",color=colors[b])
#     plt.loglog(ks,FishPrimOnlyInv[:,-1,-1]**(1/2),"-.",color=colors[b])
    
    b+=1
#     break

plt.xlim(0.3,300)
plt.ylim(1e0,1e6)
plt.xticks(ks,[str(k) for k in ks])
plt.xlabel("$k_{max}$")
plt.ylabel("$\sigma_g$")
plt.grid(linestyle=":")
plt.legend()
# plt.savefig("TrispectrumClock0.25Marginalised.pdf",format='pdf')
plt.savefig("TrispectrumClockMusError.pdf",format='pdf')
plt.show()

# %%
mus = [0.1,0.5,1,1.25,1.4]
ks = [0.3,1,3,10,30,100,300]
colors = ["tab:blue","tab:orange","tab:green","tab:red","tab:purple"]

# shapes = ["TtauNL","TgNL","Teq1","Teq2","Teq3"]
shapes = ["Teq1","Teq2","Teq3","TgNL","TtauNL"]

colors = ["tab:blue","tab:orange","tab:green","tab:red","tab:purple"]

b=0
for mu in mus:
    Fish = np.zeros((len(ks),13,13))
    FishSecOnly = np.zeros((len(ks),8,8))
    dataSec = np.genfromtxt("Secondaries7ksALTSymmetry.dat")
    dataSecClock = np.genfromtxt(f"Secondaries7ksTInt{mu}.dat")
    dataPrim = np.genfromtxt("PrimOverlaps7ks.dat")
    dataPrimClock = np.genfromtxt(f"PrimIntOverlaps7ks{mu}.dat")

    #fill the first 7x7 block with secondaries
    a = 0
    for ki in range(len(ks)):
        for S1 in range(7):
            for S2 in range(S1,7):
                Fish[ki,S1,S2] = Fish[ki,S2,S1] = dataSec[a,-2]
                a+=1
                
    FishSecOnly[:,:-1,:-1] = Fish[:,:7,:7]
                
    #fill the prim x secondaries:
    for si, shape in enumerate(shapes):
        dataSecPrim = np.genfromtxt(f"Secondaries7ks{shape}.dat")
        a = 0
        for ki in range(len(ks)):
            for S1 in range(8):
                if S1 == 7:
                    Fish[ki,7+si,7+si] = dataSecPrim[a,-2]
                else:
                    Fish[ki,S1,7+si] = Fish[ki,7+si,S1] = dataSecPrim[a,-2]
                a+=1

    #fill the prim x prim block
    a = 0
    for ki in range(len(ks)):
        for S1 in range(5):
            for S2 in range(S1,5):
                if S1 == S2:
                    sadslkfjsdf = 1
                else:
                    Fish[ki,7+S1,7+S2] = Fish[ki,7+S2,7+S1] = dataPrim[a,-2]
                a+=1

    #fill the sec x clock row&column

    a = 0
    for ki in range(len(ks)):
        for S1 in range(8):
            if S1 == 7:
                Fish[ki,-1,-1] = dataSecClock[a,-2]
            else:
                Fish[ki,S1,-1] = Fish[ki,-1,S1] = dataSecClock[a,-2]
            a+=1
            
    #fill the prim x clock parts
    a = 0
    for ki in range(len(ks)):
        for S1 in range(5):
            Fish[ki,7+S1,-1] = Fish[ki,-1,7+S1] = dataPrimClock[a,-2]
            a+=1

    FishPrimOnly = Fish[:,8:,8:]
    FishSecOnly[:,-1,-1] = Fish[:,-1,-1]
            
    FishInv = np.linalg.inv(Fish)
    FishSecOnlyInv = np.linalg.inv(FishSecOnly)
    FishPrimOnlyInv = np.linalg.inv(FishPrimOnly)
    plt.loglog(ks,Fish[:,-1,-1]**(-1/2),"--",color=colors[b])
    plt.loglog(ks,FishInv[:,-1,-1]**(1/2),label=f"$\\nu = {mu}$",linestyle="-",color=colors[b])
    plt.loglog(ks,FishSecOnlyInv[:,-1,-1]**(1/2),":",color=colors[b])
    plt.loglog(ks,FishPrimOnlyInv[:,-1,-1]**(1/2),"-.",color=colors[b])
    
    b+=1
    break

plt.xlim(0.3,300)
plt.ylim(1e0,1e5)
plt.xticks(ks,[str(k) for k in ks])
plt.xlabel("$k_{max}$")
plt.ylabel("$\sigma_g$")
plt.grid(linestyle=":")
# plt.legend()
plt.savefig("TrispectrumInt0.1Marginalised.pdf",format='pdf')
# plt.savefig("TrispectrumIntNusError.pdf",format='pdf')
plt.show()
